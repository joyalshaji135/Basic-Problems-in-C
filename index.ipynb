# %% [markdown]
# <a href="https://colab.research.google.com/github/joyalshaji135/Basic-Problems-in-C/blob/master/index.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
from skimage import data
import matplotlib.pyplot as plt
import numpy as np
from pandas import DataFrame

# %%
from scipy import misc
from PIL import Image
import imageio
import keras
from matplotlib import pyplot as plt

# %%
from skimage import io
X=[]
Y=[]
base_path='MyDrive/artificalinteligents/Covid'
source_path=base_path
for child in os.listdir(source_path):
  print(child)
  sub_path = os.path.join(source_path, child)
  bsub_path = os.path.join(base_path, child)
  if os.path.isdir(sub_path):
    for data_file in os.listdir(sub_path):
      Qry = Image.open(os.path.join(sub_path, data_file))
      Qry = Qry.convert("RGB")
      Qry = np.array(Qry.resize((224,224)))
      Qry = Qry.reshape([224,224,3])
      Qry = Qry[:,:,1]
      flist=np.array(Qry)
      X.append(flist)
      Y.append(child)
# Out:
# Copy of 7D2CF6CE-F529-4470-8356-D33FFAF98600.jpeg
# Copy of 9fdd3c3032296fd04d2cad5d9070d4_jumbo.jpeg
# Copy of 35AF5C3B-D04D-4B4B-92B7-CB1F67D83085.jpeg
# Copy of 6CB4EFC6-68FA-4CD5-940C-BEFA8DAFE9A7.jpeg
# Copy of 6b44464d-73a7-4cf3-bbb6-ffe7168300e3.annot.original.jpeg
# Copy of 7C69C012-7479-493F-8722-ABC29C60A2DD.jpeg
# Copy of 03BF7561-A9BA-4C3C-B8A0-D3E585F73F3C.jpeg
# Copy of 9C34AF49-E589-44D5-92D3-168B3B04E4A6.jpeg
# Copy of 39EE8E69-5801-48DE-B6E3-BE7D1BCF3092.jpeg
# Copy of 1-s2.0-S1684118220300608-main.pdf-001.jpg
# Copy of 4e43e48d52c9e2d4c6c1fb9bc1544f_jumbo.jpeg
# Copy of 1-s2.0-S1684118220300682-main.pdf-003-b2.png
# Copy of 1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf-001-fig2b.png
# Copy of 4ad30bc6-2da0-4f84-bc9b-62acabfd518a.annot.original.png
# Copy of 1-s2.0-S1684118220300682-main.pdf-002-a1.png
# Copy of 01E392EE-69F9-4E33-BFCE-E5C968654078.jpeg
# Copy of 1-s2.0-S0929664620300449-gr2_lrg-c.jpg
# Copy of 8FDE8DBA-CFBD-4B4C-B1A4-6F36A93B7E87.jpeg
# ...

# %%
# Import a library for image manipulation, e.g., OpenCV
import cv2

# Read an image into X (example)
image_path = images_arr
X = cv2.imread(image_path)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-19b989af790c> in <cell line: 6>()
#       4 # Read an image into X (example)
#       5 image_path = images_arr
# ----> 6 X = cv2.imread(image_path)
#
# TypeError: Can't convert object to 'str' for 'filename'
